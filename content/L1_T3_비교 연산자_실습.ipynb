# %% [markdown]
# # **Topic 3. 비교 연산자_실습**

# %% [markdown]
# **1) 다음 두 변수에 대해 이어지는 요구에 따라 크고 작음을  비교하세요.**

# %%
num1 = 50
num2 = 60

# %% [markdown]
# ① 변수 num1이 변수 num2와 같다.

# %% [markdown]
# [결과 예시]
#
# ~~~
# False
# ~~~

# %%
print( )

# %% [markdown]
# ② 변수 num1이 변수 num2 보다 크다.

# %% [markdown]
# [결과 예시]
#
# ~~~
# False
# ~~~

# %%
print( )

# %% [markdown]
# ③ 변수 num1이 변수 num2 보다 작다.

# %% [markdown]
# [결과 예시]
#
# ~~~
# True
# ~~~

# %%
print( )

# %% [markdown]
# **2) 다음 두 변수에 대해 이어지는 요구에 따라 크고 작음을  비교하세요.**

# %%
s1 = 'Hello'
s2 = 'hello'

# %% [markdown]
# ① 변수 s1이 변수 s2와 같다.

# %% [markdown]
# [결과 예시]
#
# ~~~
# False
# ~~~

# %%
print( )

# %% [markdown]
# ② 변수 s1이 변수 s2 보다 크다.

# %% [markdown]
# [결과 예시]
#
# ~~~
# False
# ~~~

# %%
print( )

# %% [markdown]
# ③ 변수 s1이 변수 s2 보다 작다.

# %% [markdown]
# [결과 예시]
#
# ~~~
# True
# ~~~

# %%
print( )

# %% [markdown]
# **3) 다음 두 변수에 대해 이어지는 요구에 따라 크고 작음을  비교하세요.**

# %%
num1 = 123
num2 = 123.0

# %% [markdown]
# ① 변수 num1이 변수 num2와 다르다.

# %% [markdown]
# [결과 예시]
#
# ~~~
# False
# ~~~

# %%
print( )

# %% [markdown]
# ② 변수 num1이 변수 num2와 같다.

# %% [markdown]
# [결과 예시]
#
# ~~~
# True
# ~~~

# %%
print( )

# %% [markdown]
# **4) 다음 두 변수에 대해 이어지는 수식을 복합 대입 연산자로 작성하고 결과를 확인하세요.**

# %%
num1 = 10
num2 = 20

# %% [markdown]
# ① num1 = num1 + 20

# %% [markdown]
# [결과 예시]
#
# ~~~
# 30
# ~~~

# %%
print(num1)

# %% [markdown]
# ② num2 = num2 - num1

# %% [markdown]
# [결과 예시]
#
# ~~~
# -10
# ~~~

# %%
print(num2)

# %% [markdown]
# ③ num1 = num1 * num2

# %% [markdown]
# [결과 예시]
#
# ~~~
# -300
# ~~~

# %%
print(num1)

# %% [markdown]
# ④ num2 = num2 / -2

# %% [markdown]
# [결과 예시]
#
# ~~~
# 10.0
# ~~~

# %%
print(num2)
