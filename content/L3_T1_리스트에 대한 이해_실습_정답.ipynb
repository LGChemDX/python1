# %% [markdown]
# # **Topic 1. 리스트에 대한 이해_실습**

# %% [markdown]
# **1) 1, 2, 3, 4, 5를 요소로 갖는 리스트 a를 선언하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [1, 2, 3, 4, 5]
# ~~~

# %%
a = [1, 2, 3, 4, 5]
print(a)

# %% [markdown]
# **2) 'a', 'b', 'c', 'd'를 요소로 갖는 리스트 b를 선언하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# ['a', 'b', 'c', 'd']
# ~~~

# %%
b = ['a', 'b', 'c', 'd']
print(b)

# %% [markdown]
# **3) 1, '홍길동', 2, '일지매'를 요소로 갖는 리스트 c를 선언하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [1, '홍길동', 2, '일지매']
# ~~~

# %%
c = [1, '홍길동', 2, '일지매']
print(c)

# %% [markdown]
# **4) 1, 2, 3, 4를 요소로 갖는 리스트 a와, 5, 6, 7, 8을 요소로 갖는 리스트 b를 선언하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [1, 2, 3, 4]
# [5, 6, 7, 8]
# ~~~

# %%
a = [1, 2, 3, 4]
b = [5, 6, 7, 8]
print(a)
print(b)

# %% [markdown]
# **5) 위에서 선언한 리스트 a와 b의 요소를 결합한 리스트 c를 선언하고 확인하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [1, 2, 3, 4, 5, 6, 7, 8]
# ~~~

# %%
c = a + b
print(c)
