# %% [markdown]
# # **Topic 1. 문자열 표현_실습**

# %% [markdown]
# **1) 문자열 '나는' 과 '너를...'을 붙여서 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 나는너를...
# ~~~

# %%
print( )
# Out:
# 나는너를...

# %% [markdown]
# **2) 문자열 '나는'과 '너를...' 사이에 한 칸 띄어서 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 나는 너를...
# ~~~

# %%
print( )
# Out:
# 나는 너를...

# %% [markdown]
# **3) '안녕하세요?' 3개와 '반갑습니다!' 2개를 하나의 print() 함수로 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 안녕하세요?안녕하세요?안녕하세요? 반갑습니다!반갑습니다!
# ~~~

# %%
print( )
# Out:
# 안녕하세요?안녕하세요?안녕하세요? 반갑습니다!반갑습니다!

# %% [markdown]
# **4) 임의의 정수를 갖는 변수 e를 선언하고, 문자열 '안녕하세요?'를 갖는 변수 f를 선언한 후 변수 f의 값을 e 개 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 안녕하세요?안녕하세요?안녕하세요?
# ~~~

# %%
e = 3
f = '안녕하세요?'
print( )
# Out:
# 안녕하세요?안녕하세요?안녕하세요?

# %% [markdown]
# **5) [결과 예시]와 같이 표시되도록 문자열을 변수 a로 선언하고 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# 이름: 홍길동
# 나이: 48
# ~~~

# %%
a =
print(a)

# %% [markdown]
# **6) [결과 예시]와 같이 표시되도록 문자열을 변수 b로 선언하고 출력하세요.**

# %% [markdown]
# [결과 예시]
#
# ~~~
# [전화번호부]
# 강우동: 010-1234-5678
# 김치국: 010-2346-1578
# 한국인: 010-3458-6712
# ~~~

# %%
b =
print(b)
